# %%
import pandas as pd
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import datetime

# %%
election_data = pd.read_csv("National Presidential Polls 2008-2020.csv")
# election_data.drop(columns=["Unnamed: 7", "Unnamed: 8"])
election_data["Democratic candidate"] = election_data["Democratic candidate"].astype(float)
election_data["Republican candidate"] = election_data["Republican candidate"].astype(float)
election_data
def plots(x):
    x["Democratic candidate"] = x["Democratic candidate"].astype(float)
    x["Republican candidate"] = x["Republican candidate"].astype(float)
    y = (x["Democratic candidate"].mean(), x["Republican candidate"].mean())
    fig1 = plt.bar(["Democratic candidate","Republican candidate"], y, color=("b", "r"))
    plt.xlabel("Party")
    plt.ylabel("Projected Vote Share")

# %%
df_08 = election_data[election_data["Cycle"] == 2008]
df_12 = election_data[election_data["Cycle"] == 2012]
df_16 = election_data[election_data["Cycle"] == 2016]
df_20 = election_data[election_data["Cycle"] == 2020]

# %%
plots(df_08)
# Out:
# C:\Users\super\anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\super\anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
plots(df_12)
# Out:
# C:\Users\super\anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\super\anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
plots(df_16)
# Out:
# C:\Users\super\anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\super\anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
plots(df_20)
# Out:
# C:\Users\super\anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\super\anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_08.head()
# Out:
#     Cycle Date administered  Democratic candidate  Republican candidate  \
# 0  2008.0        10/31/2008                  0.51                  0.43
# 1  2008.0        10/31/2008                  0.52                  0.46
# 2  2008.0        10/31/2008                  0.53                  0.40
# 3  2008.0        10/31/2008                  0.53                  0.42
# 4  2008.0        10/31/2008                  0.53                  0.42
#
#    Libertarian  Green  Undecided  Unnamed: 7  Unnamed: 8  Unnamed: 9
# 0          NaN    NaN        NaN         NaN         NaN         NaN
# 1          NaN    NaN        NaN         NaN         NaN         NaN
# 2          NaN    NaN        NaN         NaN         NaN         NaN
# 3          NaN    NaN        NaN         NaN         NaN         NaN
# 4          NaN    NaN        NaN         NaN         NaN         NaN

# %%
# fig = go.Figure()
# fig.add_trace(go.Scatter(x = df_08["Date administered"], y= df_08["Republican candidate"], mode='markers'))
df_08['Date administered'] = pd.to_datetime(df_08['Date administered'])

px.scatter(x = df_08["Date administered"], y= df_08["Republican candidate"])
# Out:
# C:\Users\super\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <div>
#
#
#             <div id="901edcb9-4764-430a-9cf0-4f8ca34470e3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("901edcb9-4764-430a-9cf0-4f8ca34470e3")) {
#                     Plotly.newPlot(
#                         '901edcb9-4764-430a-9cf0-4f8ca34470e3',
# ...

# %%
px.scatter(x = df_08["Date administered"], y= df_08["Republican candidate"])
# Out:
# <div>
#
#
#             <div id="55d3d008-fc32-4b03-bc89-5c2e9e943edb" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("55d3d008-fc32-4b03-bc89-5c2e9e943edb")) {
#                     Plotly.newPlot(
#                         '55d3d008-fc32-4b03-bc89-5c2e9e943edb',
# ...
